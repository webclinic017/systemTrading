# %% [markdown]
# # 상관계수에 따른 리스크 완화

# %% [markdown]
# ## 3.7.4
# 다우존스 지수와 KOSPI의 회긔 분석

# %%
import pandas as pd
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
from scipy import stats
import matplotlib.pylab as plt

# %%
dow = pdr.get_data_yahoo('^DJI', '2000-01-04')
kospi = pdr.get_data_yahoo('^KS11', '2000-01-04')

df = pd.DataFrame({'X': dow['Close'], 'Y': kospi['Close']})
df = df.fillna(method='bfill')
df = df.fillna(method='ffill')

regr = stats.linregress(df.X, df.Y)
regr_line = f'y = {regr.slope:.2f} * X + {regr.intercept:.2f}'
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(7,7))
plt.plot(df.X, df.Y, '.')
plt.plot(df.X, regr.slope * df.X + regr.intercept, 'r')
plt.legend(['DOW x KOSPI', regr_line])
plt.title(f'DOW x KOSPI (R = {regr.rvalue:.2f})')
plt.xlabel('Dow Jones Industrial Average')
plt.ylabel('KOSPI average')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-389cb6bc4a3d> in <module>
#       3 plt.plot(df.X, regr.slope * df.X + regr.intercept, 'r')
#       4 plt.legend(['DOW x KOSPI', regr_line])
# ----> 5 plt.title(f'DOW x KOSPI (R = {regre.rvalue:.2f})')
#       6 plt.xlabel('Dow Jones Industrial Average')
#       7 plt.ylabel('KOSPI average')
#
# NameError: name 'regre' is not defined
